# %% [markdown]
# <a href="https://colab.research.google.com/github/lashkoEv/lessons/blob/master/1_intro_variables_simple_data_types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Интро

# %% [markdown]
# Python - высокоуровневый кроссплатформенный язык программирования общего назначения.
#
# Выпускается с 1991 года.
#
# Основной создатель - Гвидо Ван Россум.
#
# Высокоуровневый - нам не надо писать машинный код или напрямую обращаться к памяти, мы пишем команды на английском языке, а потом интерпритатор и компилятор преобразовывают его в байт-код и машинный код.
#
# Кроссплатформенный - запускается на множестве платформ (Windows, Linux, iOS, Android и т.д.), а так же на микроконтроллерах, суперкомпьютерах и т.д.
#
# Общего назначения - можно делать множество вещей:
#
#     - веб-разработка (Django, Flusk...)
#
#     - графика (PyQt, wxPython...)
#
#     - тестрирование (Seleniun...)
#
#     - data science (numPy, Pandas, scyPy...)
#
#     - мат. графики (matplotlib...)
#
#     - нейронные сети (Keras TensorFlow...)
#
#     - и т.д.

# %% [markdown]
# ### Переменные

# %% [markdown]
# Переменная - именованная область памяти, предназначенная для храненния данных ("коробочка" для любых данных, нужна чтобы по имени коробочки получить эти данные).
#
# ![image.png](data:image/png;base64,...)
#
# Правила именования переменных:
#
#     - имя должно начинаться с буквы или _ (не с цифры или знака)
#
#     - имя может включать буквы, цифры, _, но не другие символы
#
#     - регистрозависимость (a = 5 и A = 5 это две разные переменные)
#
#     - имя не может быть ключевым словом (def, if, for, while, ilif, else, class, type ...)
#
# В Python принято именование через snake_case (some_variable = 5)

# %%
# определение (объявление, инициализация)

# ! Нельзя обявить и не проинициализировать переменную!
# number
# ...
# number = 3

my_number = 10

my_string = 'Hello world!'

# %%
# Переопределение

number = 5
number = 8

print(number) # 8
# Out:
# 8

# %%
# Множественное объявление и инициализация

a = b = c = 10

x, y, z = 1, 2, 3

# %% [markdown]
# ### Ввод / вывод

# %% [markdown]
# Встроенные функции для вывода - **print()**, **display()**.
#
# print() можно передавать бесчисленное количество аргументов, значения будут выводиться через пробел:
# print(a, b, c, ..... n)

# %%
# print(), display()

string = 'Hello world!'

print(string)
# Out:
# Hello world!

# %%
first = 'Hello'
second = 'world'
third = '!'

print (first, second, third)
# Out:
# Hello world !

# %% [markdown]
# Встроенная функция для ввода с клавиатуры - **input()**.
#
# В input() можно передать промпт (подпись) для пользователя.
#
# Значение, которое ввёл пользователь, лучше сохранять в переменную чтобы потом с ним работать.
#
# input() **ВСЕГДА** возвращает строку. Независимо от того, что введёт пользователь.
#
# Чтобы посмотреть тип какого-то значения существует встроенная функция **type()**.

# %%
# input()

variable = input()

print(variable, type(variable))
# Out:
# 123 <class 'str'>

# %%
city = input('Введите город: ')

print('Введённый город:', city)
# Out:
# Введённый город: Днепр

# %% [markdown]
# ### Простые типы данных

# %% [markdown]
# ##### Числовые
#
#     - int (целочисленный): 1, 5, 5000, -49
#
#     - float (вещественный, с плавающей точкой): 1.0, -1.25, -5e2
#
#     - complex (комплексное число: [вещественная_часть]+[мнимая_часть]j): 1+2j
#
#
# ##### Текстовые (строковые)
#
#     - str: '...', "...", '''...'''
#
#     - f-строка: f'... {} ...'
#
# ##### Логические
#
#     - boolean: True (истина), False (ложь)
#
#
# ##### NoneType
#
#     - None - ничто

# %%
# f-строка использует интерполяцию строк (прямая вставка литерала (значения) или переменной в строку)

a = 5
b = 10
c = a + b

f_string = f'{a} + {b} = {c}'

print(f_string)

print(f'a is {a}, b is {b}, result of a + b is {a + b}')
# Out:
# 5 + 10 = 15
# a is 5, b is 10, result of a + b is 15
